# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_csv("data/preprocessed_data.csv")

# %% [markdown]
# sử dụng EDA của Tùng để bỏ bớt 1 số trường có thể map 1-1 với các trường khác, hoặc các trường có ít correlation với giá

# %%
df.drop(
    [
        'url',
        'date',
        'out_color',
        'in_color',
        'num_door',
        'num_seat',
        'gear_type',
        'drive_type',
        'cylinder_capacity'
    ],
    axis=1,
    inplace=True
)

# %%
df
# Out:
#            brand    serie  model_year  price_vnd              origin  \
# 0           Ford    Focus      2018.0        478  Lắp ráp trong nước
# 1          Mazda      CX5      2021.0        999  Lắp ráp trong nước
# 2            Kia   Cerato      2018.0        510  Lắp ráp trong nước
# 3          Isuzu     Dmax      2021.0        580           Nhập khẩu
# 4            Kia  Sorento      2021.0       1230  Lắp ráp trong nước
# ...          ...      ...         ...        ...                 ...
# 41608  Hãng khác      NaN         NaN         65  Lắp ráp trong nước
# 41609     Toyota  Corolla      2002.0        155  Lắp ráp trong nước
# 41610       Ford   Ranger      2016.0        675           Nhập khẩu
# 41611   Chrysler     300C      2008.0        555           Nhập khẩu
# 41612    Hyundai       HD      2016.0        599           Nhập khẩu
#
#            status            category  used_distance
# 0      Xe đã dùng               Sedan              0
# 1          Xe mới                 SUV              0
# 2      Xe đã dùng               Sedan              2
# 3          Xe mới  Bán tải / Pickup              0
# 4      Xe đã dùng                 SUV              0
# ...           ...                 ...            ...
# 41608  Xe đã dùng               Truck              0
# 41609  Xe đã dùng               Sedan              0
# 41610  Xe đã dùng  Bán tải / Pickup              0
# 41611  Xe đã dùng               Sedan          58000
# 41612      Xe mới               Truck              0
#
# [41613 rows x 8 columns]

# %%
df['age'] = datetime.datetime.now().year - df['model_year']

# %% [markdown]
# ### Phân tích ban đầu
#
# Các thông tin có thể validate:
# - used_distance: Dựa vào số km/năm (vd: ko thể chạy quá 15v km/năm)
# - status: đối chiếu với used_distance, xe mới thì used_distance phải = 0, hoặc nếu xe đã dùng mà used_distance = 0 thì phải xem xét sửa used_distance thành trung bình km/năm x số năm.
#
# Các thông tin ko thể validate:
# - model_year/năm
# - brand, series

# %% [markdown]
# ## validate used_distance
#
# - Nhận định: với các xe > 15v/năm, điền bừa, hoặc model_year bị sai -> lọc bỏ

# %%
df_valid_used_distance = df[df.used_distance/df.age < 15000]

# %%
df[df.used_distance/df.age > 150000]
# Out:
#             brand          serie  model_year  price_vnd              origin  \
# 2402         Ford         Ranger      2016.0        760           Nhập khẩu
# 2729       Toyota         Innova      2009.0        265  Lắp ráp trong nước
# 5007          Kia         Soluto      2019.0        350  Lắp ráp trong nước
# 8603          Kia        Morning      2016.0        220  Lắp ráp trong nước
# 9724         Ford        Everest      2022.0       1190           Nhập khẩu
# ...           ...            ...         ...        ...                 ...
# 39855  Mitsubishi         Triton      2019.0        785           Nhập khẩu
# 39983         Kia         Cerato      2016.0        465  Lắp ráp trong nước
# 40152     Hyundai            i10      2019.0        280  Lắp ráp trong nước
# 40198      Toyota   Land Cruiser      1997.0        200           Nhập khẩu
# 40555      Toyota  Corolla altis      2003.0        228  Lắp ráp trong nước
#
#            status            category  used_distance   age
# 2402   Xe đã dùng  Bán tải / Pickup        1000000   6.0
# 2729   Xe đã dùng           Crossover        2031509  13.0
# 5007   Xe đã dùng               Sedan       40000000   3.0
# 8603   Xe đã dùng           Hatchback        6600000   6.0
# 9724       Xe mới                 SUV           1086   0.0
# ...           ...                 ...            ...   ...
# 39855  Xe đã dùng  Bán tải / Pickup        2600000   3.0
# 39983  Xe đã dùng               Sedan        1000000   6.0
# 40152  Xe đã dùng               Sedan         650000   3.0
# 40198  Xe đã dùng                 SUV        9999999  25.0
# 40555  Xe đã dùng               Sedan       16000086  19.0
#
# [120 rows x 9 columns]

# %% [markdown]
# #### Phân tích used_distance của xe đã dùng
#
# validate xe đã dùng: 12297/31086 là ko có dữ liệu used_distance (= 0)
# - approach 1: sửa lại toàn bộ sử dụng used_distance TB theo age
# - approach 2: với các xe age < 3 năm, để yên và chuyển thành xe mới (nhầm status). các xe >= 3 năm sửa lại thành TB theo age.

# %%
df_used = df[df.status == "Xe đã dùng"]
df_used_0_distance = df_used[df_used.used_distance == 0]
print(f"{len(df_used_0_distance)}/{len(df_used)}")
# Out:
# 12297/31086

# %% [markdown]
# Sử dụng xe đã dùng với used_distance>0 để xây dựng used_distance trung bình theo age. Mục đích để sau lấy giá trị điền vào các hàng mà used_distance bị sai

# %%
df_used_car = df_valid_used_distance[df_valid_used_distance["status"] == "Xe đã dùng"]
df_valid_used_distance = df_valid_used_distance.drop(df_used_car[df_used_car.used_distance == 0].index)

# %%
df_mean_distance_by_age = df_valid_used_distance.groupby(["age"]).mean()
df_mean_distance_by_age["used_distance"] = df_mean_distance_by_age["used_distance"].astype("int")
df_mean_distance_by_age
# Out:
#       model_year    price_vnd  used_distance
# age
# 1.0       2021.0  1795.695614            310
# 2.0       2020.0  1737.674692           9926
# 3.0       2019.0  1199.125169          23383
# 4.0       2018.0  1086.413697          33782
# 5.0       2017.0   999.474932          44948
# 6.0       2016.0  1112.166572          53629
# 7.0       2015.0   941.352236          60080
# 8.0       2014.0  1025.280682          62941
# 9.0       2013.0   773.799302          70324
# 10.0      2012.0   608.213992          72881
# 11.0      2011.0   500.437781          79023
# 12.0      2010.0   526.460403          82231
# 13.0      2009.0   458.284314          86522
# 14.0      2008.0   425.728682          92056
# 15.0      2007.0   375.876640         104640
# 16.0      2006.0   332.190840         101762
# 17.0      2005.0   216.356725         113031
# 18.0      2004.0   189.362637         102243
# 19.0      2003.0   168.510204         113003
# 20.0      2002.0   180.924242         127618
# 21.0      2001.0   147.321429         114080
# 22.0      2000.0   102.418605         109189
# 23.0      1999.0   149.900000          90822
# 24.0      1998.0   133.000000         102843
# 25.0      1997.0   156.275862         105351
# 26.0      1996.0   112.000000         154340
# 27.0      1995.0   147.550000         121079
# 28.0      1994.0   169.923077         181612
# 29.0      1993.0   124.933333         147916
# 30.0      1992.0   462.142857         134242
# 31.0      1991.0   158.200000         147069
# 32.0      1990.0   153.750000         194620

# %%
# approach 1: sửa tất cả 
def lambda_func(x):
    if x.status == "Xe đã dùng" and x.used_distance == 0:
        if x["age"]>0: 
            return df_mean_distance_by_age.loc[x["age"]].used_distance
        else:
            return x.used_distance
    else:
        return x.used_distance

# %%
df
# Out:
#            brand    serie  model_year  price_vnd              origin  \
# 0           Ford    Focus      2018.0        478  Lắp ráp trong nước
# 1          Mazda      CX5      2021.0        999  Lắp ráp trong nước
# 2            Kia   Cerato      2018.0        510  Lắp ráp trong nước
# 3          Isuzu     Dmax      2021.0        580           Nhập khẩu
# 4            Kia  Sorento      2021.0       1230  Lắp ráp trong nước
# ...          ...      ...         ...        ...                 ...
# 41608  Hãng khác      NaN         NaN         65  Lắp ráp trong nước
# 41609     Toyota  Corolla      2002.0        155  Lắp ráp trong nước
# 41610       Ford   Ranger      2016.0        675           Nhập khẩu
# 41611   Chrysler     300C      2008.0        555           Nhập khẩu
# 41612    Hyundai       HD      2016.0        599           Nhập khẩu
#
#            status            category  used_distance   age
# 0      Xe đã dùng               Sedan              0   4.0
# 1          Xe mới                 SUV              0   1.0
# 2      Xe đã dùng               Sedan              2   4.0
# 3          Xe mới  Bán tải / Pickup              0   1.0
# 4      Xe đã dùng                 SUV              0   1.0
# ...           ...                 ...            ...   ...
# 41608  Xe đã dùng               Truck              0   NaN
# 41609  Xe đã dùng               Sedan              0  20.0
# 41610  Xe đã dùng  Bán tải / Pickup              0   6.0
# 41611  Xe đã dùng               Sedan          58000  14.0
# 41612      Xe mới               Truck              0   6.0
#
# [41613 rows x 9 columns]

# %%
df["clean_used_distance"] = df.apply(lambda x: lambda_func(x), axis=1)

# %%
df_new_car = df[df.status == "Xe mới"]
index_wrong_status = df_new_car[df_new_car.used_distance > 0].index
df.at[index_wrong_status,"status"] = "Xe đã dùng"

# %%
cat_columns_df = df[['brand', 'serie', 'origin', 'status', 'category']]
numeric_columns_df = df[['price_vnd', 'used_distance', 'age']]

# %%
df = pd.concat([numeric_columns_df, pd.get_dummies(cat_columns_df)], axis=1)

# %%
df = df.dropna()

# %% [markdown]
# # ML

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df.drop(['price_vnd'], axis=1), 
    df['price_vnd'],
    test_size=0.2
)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Evaluation

# %%
from helpers.evaluation import get_summary_result

# %%
get_summary_result(model, X_test, y_test)
# Out:
# {'Model': 'LinearRegression', 'Hyperparams': "{'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False, 'positive': False}", 'R2': 0.7761625727136361, 'RMSE': 897.804497209276, 'MAE': 313.43030616121416, 'MAPE': 2.812415671706137, 'Time': '22:48:45 26-03-2022'}
